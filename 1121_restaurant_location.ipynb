# %%
import pandas as pd

# %%
df = pd.read_excel("C:/crawring/restaurant_location_geo.xlsx")
df
# Out:
#         brand   city        store  \
# 0       연돈볼카츠  서울특별시       이마트용산점
# 1         빽다방  서울특별시    잠실레이크팰리스점
# 2       빽보이피자  서울특별시         노원역점
# 3         빽다방  서울특별시     이태원경리단길점
# 4        제순식당  서울특별시   연세대SK국제학사점
# ..        ...    ...          ...
# 534  미정국수0410  서울특별시      구로디지털역점
# 535      돌배기집  서울특별시      구로디지털역점
# 536      돌배기집  서울특별시        영등포역점
# 537      구내식당  서울특별시         논현본점
# 538   백's 비빔밥  서울특별시  Isu Station
#
#                                           address   Latitude   Longitude  \
# 0    서울 용산구 한강대로23길 55 (한강로3가, 용산역) 지하2층 이마트용산점 內  37.529444  126.965556
# 1                                서울 송파구 석촌호수로 144  37.506905  127.092979
# 2      서울 노원구 상계로1길 14-11 (상계동, 하이웰빙상가) 하이웰빙상가 1층  37.657018  127.061749
# 3                                서울 용산구 회나무로13길 5  37.539481  126.989270
# 4          서울 서대문구 연세로 50 연세대학교 신촌캠퍼스 SK국제학사, B2층  37.565784  126.938572
# ..                                            ...        ...         ...
# ...

# %%
df2 = pd.read_csv("C:/crawring/restaurant_location.csv")
df2.head()
# Out:
#    brand   city       store                                       address  \
# 0  연돈볼카츠  서울특별시      이마트용산점  서울 용산구 한강대로23길 55 (한강로3가, 용산역) 지하2층 이마트용산점 內
# 1    빽다방  서울특별시   잠실레이크팰리스점                              서울 송파구 석촌호수로 144
# 2  빽보이피자  서울특별시        노원역점    서울 노원구 상계로1길 14-11 (상계동, 하이웰빙상가) 하이웰빙상가 1층
# 3    빽다방  서울특별시    이태원경리단길점                              서울 용산구 회나무로13길 5
# 4   제순식당  서울특별시  연세대SK국제학사점        서울 서대문구 연세로 50 연세대학교 신촌캠퍼스 SK국제학사, B2층
#
#             telephone                          openhour
# 0                 미등록  10:00 ~21:00(브레이크타임 13:30~15:00)
# 1       070-8287-1231                     08:00 ~ 22:00
# 2  포장 주문 번호 1668-1931                     11:00 ~ 22:00
# 3       070-4070-6616                     10:00 ~ 21:00
# 4                   -                     11:00 ~ 19:00

# %%
openhour = df2["openhour"].tolist()
len(openhour)
# Out:
# 539

# %%
df["openhour"] = openhour

# %%
df.to_csv("C:/crawring/restaurant_location_info.csv", encoding="utf-8-sig", index = False)
